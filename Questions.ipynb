# %% [markdown]
# # Questions to think about in the future
# These are questions that I did not have the time to reflect on while they arise, but I hope to understand better later

# %% [markdown]
# -I don't understand the equation of a plane. This question arised when reading about uniform plane waves in *Elements of electromagnetism* by M. Sadiku in p451.
